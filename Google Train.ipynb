# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv('Google_Stock_Price_Train.csv')
df.plot(style='o-')
# Out:
# <Axes: >

# %%
df.plot(kind = 'scatter', x = 'Low', y = 'High')
# Out:
# <Axes: xlabel='Low', ylabel='High'>

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind='barh')
# Out:
# <Axes: >
# Error in callback <function flush_figures at 0x000001C87E0DB1A0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...

# %%
df.plot(kind='line')
# Out:
# Running cells with 'new_env_name (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n new_env_name ipykernel --update-deps --force-reinstall'

# %%
df.plot.box()
# Out:
# Running cells with 'new_env_name (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n new_env_name ipykernel --update-deps --force-reinstall'

# %%
df.plot.kde()
# Out:
# Running cells with 'new_env_name (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n new_env_name ipykernel --update-deps --force-reinstall'

# %%
df.plot(kind='density')
# Out:
# Running cells with 'new_env_name (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n new_env_name ipykernel --update-deps --force-reinstall'

# %%
df.plot(kind='area')
# Out:
# Running cells with 'new_env_name (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n new_env_name ipykernel --update-deps --force-reinstall'

# %%
df.plot(kind='scatter', x = 'Close', y = 'Volume')
# Out:
# Running cells with 'new_env_name (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n new_env_name ipykernel --update-deps --force-reinstall'

# %%
df.plot(kind='hexbin', x = 'Low', y = 'High')
# Out:
# Running cells with 'new_env_name (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n new_env_name ipykernel --update-deps --force-reinstall'
